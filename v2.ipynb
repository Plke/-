# %%
import requests
from bs4 import BeautifulSoup
import re
# 发送HTTP请求获取网页内容

book_name="战争世界马旒斯"
url_root = "http://www.xbiquzw.com/"
search_response = requests.get(url_root+"modules/article/search.php?searchkey="+book_name)
# 使用Beautiful Soup解析HTML内容
search_soup = BeautifulSoup(search_response.text, "html.parser")
#获取"#wrapper > table > tbody" tbody
tbody = search_soup.select_one("#wrapper>table")

# %%
#遍历tbody下的tr，从第二个开始
for tr in tbody.find_all('tr'):
    #获取第一个td
    td = tr.find('td')
    if(td==None):
        continue
    #获取a标签
    a = td.find('a')
    #获取内容
    book_title = a.get_text()
    if(book_title==book_name):
        #获取href
        href = a.get('href')
        #跳转
        book_url = url_root+href
        book_response = requests.get(book_url)
        book_soup = BeautifulSoup(book_response.text, "html.parser",from_encoding="utf-8")
        #list > dl
        dl = book_soup.select_one("#list>dl")
        #遍历dl下的dd
        with open(book_name+".txt", "a", encoding="utf-8") as f:
            for dd in dl.find_all('dd'):
                #获取a标签
                a = dd.find('a')
                #获取内容
                href = a.get('href')

                chapter_title = a.get('title').encode("latin1").decode("utf-8")

                print(chapter_title)

                chapter_url=book_url+href
                chapter_response = requests.get(chapter_url)
                chapter_soup = BeautifulSoup(chapter_response.text, "html.parser",from_encoding="utf-8")
                content = chapter_soup.select_one("#content")
                #获取内容,包括html
                #获取div中的内容
                
                content_text = content.encode("latin1").decode("utf-8", errors="ignore")
                pattern = re.compile(r'<!--go-->\s*(.*?)\s*<!--over-->', re.S)
                content_text = pattern.search(content_text).group(1).strip()
                #写入文件
                
                f.write("\n\n"+chapter_title+'\n\n')
                f.write(content_text.replace("<br/>", "\n"))
# Out:
# 第一章 战争世界
# 第二章 创建人物
# 第三章 兵种选择
# 第四章 初始部下
# 第五章 初次战斗
# 第六章 图鉴开启
# 第七章 接连遭遇
# 第八章 初遇村庄
# 第九章 协助防守
# 第十章 橡木村
# 第十一章 神秘的圣女
# 第十二章 镇守橡木村
# 第十三章 华美斯
# 第十四章 小橡果酒馆
# 第十五章 捕猎任务
# 第十六章 英雄光环的威力
# 第十七章 野兽人的来源
# 第十八章 劣角兽
# 第十九章 继续狩猎
# 第二十章 混沌猎犬
# 第二十一章 特殊精英-猎手约翰
# 第二十二章 华美斯的小秘密
# 第二十三章 骑士之道
# 第二十四章 重伤的战士
# 第二十五章 战友的遗物
# 第二十六章 狼牙项链
# 第二十七章 战士达维
# 第二十八章 轻松的战斗
# 第二十九章 约翰的小请求
# 第三十章 亵渎，还是。。。
# 第三十一章 英雄！
# 第三十二章 华美斯的请求
# 第三十三章 目标：摩尔花园
# 第三十四章 危险的白河
# 第三十五章 鱼人的战利品
# 第三十六章 诡异的摩尔花园
# 第三十七章 初遇不死族
# 第三十八章 进入摩尔圣殿
# 第三十九章 地下大厅
# 第四十章 羊头野兽人
# 第四十一章 意外的闯入者
# 第四十二章 昏迷的摩尔骑士
# 第四十三章 偶遇豺狼人
# 第四十四章 圣女出手
# 第四十五章 论坛的日常
# 第四十六章 意外中止的任务
# 第四十七章 昂贵的坐骑
# 第四十八章 神秘游商
# 第三百零八章 鱼人的进攻（下）
# 第三百零九章 娜迦的主力
# 第三百一十章 埃厄斯的奋战
# 第三百一十一章 诡异的大雨
# 第三百一十二章 李维斯的突袭
# 第三百一十三章 成功的突袭
# 第三百一十四章 娜迦祭祀的后手
# 第三百一十五章 魔法对决
# 第三百一十六章 转进娜迦村落
# 第三百一十七章 娜迦村落的乱战
# 第三百一十八章 暗光村
# 第三百一十九章 欧菲妮的发现
# 第三百二十章 功勋兑换与新部下加入
# 第三百二十一章 目标穆席隆
# 第三百二十二章 伏行龙兽与尸骸猎犬
# 第三百二十三章 贪吃的龙兽
# 第三百二十四章 意外的遭遇
# 第三百二十五章 鼠人的新式部队
# 第三百二十六章 激战鼠人
# 第三百二十七章 鼠人的反击
# 第三百二十八章 李维斯的战法
# 第三百二十九章 恼怒的灰先知
# 第三百三十章 强大的灰先知
# 第三百三十一章 意外的援军
# 第三百三十二章 和哈巴卡克的短暂重逢
# 第三百三十三章 圣灵印记
# 第三百三十四章 末日使船
# 第三百三十五章 甩锅与分赃
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\python\Python37\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     747         try:
# --> 748             self.chunk_left = int(line, 16)
#     749         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# InvalidChunkLength                        Traceback (most recent call last)
# d:\python\Python37\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     442             try:
# --> 443                 yield
#     444
#
# d:\python\Python37\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     814             while True:
# --> 815                 self._update_chunk_length()
#     816                 if self.chunk_left == 0:
#
# d:\python\Python37\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     751             self.close()
# --> 752             raise InvalidChunkLength(self, line)
#     753
#
# InvalidChunkLength: InvalidChunkLength(got length b'', 0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# d:\python\Python37\lib\site-packages\requests\models.py in generate()
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#
# d:\python\Python37\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     622         if self.chunked and self.supports_chunked_reads():
# --> 623             for line in self.read_chunked(amt, decode_content=decode_content):
#     624                 yield line
#
# d:\python\Python37\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     843             if self._original_response:
# --> 844                 self._original_response.close()
#     845
#
# d:\python\Python37\lib\contextlib.py in __exit__(self, type, value, traceback)
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#
# d:\python\Python37\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     459                 # This includes IncompleteRead.
# --> 460                 raise ProtocolError("Connection broken: %r" % e, e)
#     461
#
# ProtocolError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17300\1290875322.py in <module>
#      31
#      32                 chapter_url=book_url+href
# ---> 33                 chapter_response = requests.get(chapter_url)
#      34                 chapter_soup = BeautifulSoup(chapter_response.text, "html.parser",from_encoding="utf-8")
#      35                 content = chapter_soup.select_one("#content")
#
# d:\python\Python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# d:\python\Python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# d:\python\Python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# d:\python\Python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     745
#     746         if not stream:
# --> 747             r.content
#     748
#     749         return r
#
# d:\python\Python37\lib\site-packages\requests\models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# d:\python\Python37\lib\site-packages\requests\models.py in generate()
#     816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
# --> 818                     raise ChunkedEncodingError(e)
#     819                 except DecodeError as e:
#     820                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
